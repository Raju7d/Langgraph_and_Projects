# %% [markdown]
# # Agenti AI Chatbot
#
# ## Agenda
#
# 1. Chatbot with Langgraph + tool intergration (Multiple tools)
# 2. ReAc
# t Architecture (Reasoning + Act)
#
#
# 1. In Langgraph we have a **ToolNode** that is integrated with some tools.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ReACT architure
#
# 1. The AI Assistant is basically takes the input. and think about the query using LLM (reasoning) and then act. (Reasoning + Act)
# 2. Once request comes, the Tool call Node (Ai Assistant), This Ai assistant (Node), decides whethere there is a tool call or not
# 3. If there is no Tool call, It will just gives the output and END
# 4. if there is a tool call, it will make a tool call,based on i/p we basically call that specific tool and get the output and goes to the END
#
# ## Example Question
# ###  Tell me about Research paper (research paper number) then search fro AI Agent or AI
#
# here i have 2 questions
# 1. tell me about the research paper
# 2. Search for AI agent
#
#
# ### Now the AI assistant understand the what is the user query
#
# 1. after this seeing this input, The AI assistant think like whether i need to make a tool call
#
# 2. based input the ai assistnt make a tool because it has a research paper query which will available on arxiv tool
#
# 3. still some more input left
#
# 4. now AI asiistnt think like whether i can provide answer or tool call
#
# 5. it will answer directly without calling a tool
#
# 6. END

# %% [markdown]
# # Langgraph

# %% [markdown]
# ## Building  Agentic AI system with Langgraph
#
# ### Agenda
#     1. Pydantic (data validation) -> Completed
#     2. Langgraph + Langsmith
#     3. Work flows using Langgraph
#     4. RAG using Langgraph
#     5. AI agents vs Agentic AI system

# %% [markdown]
# 1. what is difference between AI agents vs Agentic AI?
# 2. What is Langgraph and Why?
# 3. Build one simple workflow Using Langgraph(simple use case).
#                 a. graphs
#                 b. Node
#                 c. functions

# %% [markdown]
# ##### AI Agents:
#     1. AI agnets refers to s/w program designed to perform specific tasks without human intervention with a degree of
#     2. ex: if you a specific LLM(OpenAI older model), will you able to get the answer for latest questions,
#     3. SO WE NEED TO CONNECT THIS TO SOME EXTERNAL SOURCE (API/TOOL)(DB,WEBSITES, ETC) AND RETURNS JSON OUTPUT. THIS PROCESS WE WILL CALL IT AS A AI AGENT. LLM IS SMART ENOUGH TO CALL THE API, IF IT IS DOESN'T FIND(USING ID OR UNIQUE IDENTIFIER) A ANSWER IN IT.
#     4. Here one input and one output
#
#
#
# ##### Agentic AI Systems:
#     1. Agentic AI systems are Frames=works where multiple AI agents can collaborate  and make decisions independently to achieve a larger goal.
#     2. Agentic AI system is a broader framework, instead of single agent, multiple AI Agents will be available and they can communicate with each other, to solve a problem or goal
#     3. ex: if you have Youtube videos, you need to convert them into Blog content (title, description, code part and conclusion part), if you don't use AI agent, the person should have good coding knowledge and content writing idea
#     4.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# YT video to blog generation
#
# 1. first we need to take the Youtube video
# 2. Then convert the Video into Transcript (using code or anything)
# 3. now convert the transcript into Title, description, code part and conclusion (using multiple agents)
# 4. finally create a Blog
# 5. This is a Normal flow, let's see Langgraph flow

# %% [markdown]
# ## Langgraph Flow

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. The input is Youtube url
# 2. youtube - trnascript (agent will convert the url to transcript)
# 3. Blog generation another agent
# 4. The agents can take feedback (regenerate)
# 4. end

# %% [markdown]
# ### Key terminology

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. *Nodes* ==> Python Functions ==> Tasks (nodes basically tasks or python funcs). as per diagram nodes are tasks -> cricket or badmintion
# 2. *Edges* -> Edges connects the Nodes (we have a conditional edge as well). as per dig, whether i can play cricket or badmintion and i will end my day
# 3. *State* => state is nothing but a schema, it serves as the input for all nodes. ex: (Title, description, code part and conclusion) these are state variables that needs to pass every node. where this will store? it will store in the schema
# 4. *State graph* => structure of the entire graph

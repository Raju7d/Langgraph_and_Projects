# %% [markdown]
# # Langgraph Contents
#
# ## 1. Langgraph Fundamentals
#
# 1. Build a Basic Chatbot
# 2. Tools and Multiple Tools
# 3. Adding Memory
# 4. Add Human in the loop
# 5. Streaming Techniques
# 6. MCP - from stracth
#
# ## 2. Advanced LangGraph
#
# 1. Workflows and Agents
# 2. Multi Agents
# 3. Functional API
# 4. Debugging and Monitoring
#
#
# ## 3. LangGraph Agents [End to End Projects]
#
# 1. LLMoPS Pipeline
# 2. Deployments
# 3. LLM Evaluation
